# %% [markdown]
# # Fase 4 — CNN aplicada a ECG
#
# Notebook inicial para experimentos com classificação de ECG por CNN.

# %% [markdown]
# ## Objetivos
#
# - carregar imagens de ECG a partir de `data/raw/`
# - treinar uma CNN simples
# - avaliar accuracy, precision, recall e F1-score
# - gerar matriz de confusão
# - discutir limitações médicas e risco de overfitting

# %% [markdown]
# ## Estrutura esperada dos dados
#
# ```text
# data/raw/ecg_images/
# ├── normal/
# ├── mi/
# ├── abnormal/
# └── ...
# ```

# %%
from pathlib import Path

project_root = Path.cwd().resolve().parents[2]
data_dir = project_root / 'data' / 'raw' / 'ecg_images'
data_dir

# %% [markdown]
# ## Próximos passos sugeridos
#
# 1. validar a estrutura das classes
# 2. carregar imagens com TensorFlow/Keras
# 3. treinar uma CNN pequena
# 4. salvar gráficos em `outputs/figures/`
# 5. registrar análise crítica em `reports/`
